# %% [markdown]
# #DATA SCIENCE

# %% [markdown]
# #*Seaborn*
# Python data visualization library built on top of Matplotlib.
#
# It provides:
# - Better-looking default plots
# - Statistical visualizations
# - Easier syntax
# - Tight integration with Pandas DataFrames
#
#
# Seaborn code
#
# sns.scatterplot(data=df,
#                 x="Hours",
#                 y="Marks")
#
# plt.show()

# %% [markdown]
# #Main Seaborn Modules / Components
# Unlike Matplotlib, Seaborn doesn't have many subpackages that users directly import.
#
# Commonly used modules are:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Student": ["A","B","C","D","E","F"],
    "Hours": [2,3,4,5,6,7],
    "Math": [60,65,72,80,90,95],
    "Science": [58,68,70,82,88,96]
})

# %% [markdown]
# #seaborn.relational
#
# For relationship plot and Trends.
#
# Example
# - sns.scatterplot()
# - sns.lineplot()

# %% [markdown]
# Line plot

# %%
sns.lineplot(
    data=df,
    x="Hours",
    y="Math"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       1 sns.lineplot(
#       2     data=df,
#       3     x="Hours",
#       4     y="Math"
#       5 )
# ----> 7 plt.show()
#
# File ~/anaconda3/lib/python3.13/site-packages/matplotlib/_api/__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(
    data=df,
    x="Hours",
    y="Math"
)

plt.show()

# %% [markdown]
# #seaborn.categorical
# For categorical data.
#
# Graph Used:
# - sns.barplot()
# - sns.countplot()
# - sns.boxplot()
# - sns.violinplot()
# - sns.stripplot()
# - sns.swarmplot()

# %% [markdown]
# Bar plot

# %%
sns.barplot(
    data=df,
    x="Student",
    y="Math"
)

plt.show()

# %% [markdown]
# Count plot

# %%
sns.countplot(
    data=df,
    x="Student"
)

plt.show()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(
    data=df,
    y="Math"
)

plt.show()

# %% [markdown]
# Violin plot

# %%
sns.violinplot(
    data=df,
    y="Math"
)

plt.show()

# %% [markdown]
# Strip plot

# %%
sns.stripplot(
    data=df,
    y="Math"
)

plt.show()

# %% [markdown]
# Swarm plot

# %%
sns.swarmplot(
    data=df,
    y="Math"
)

plt.show()

# %% [markdown]
# #seaborn.distributions
# For distributions.
#
# Graph Used:
# - sns.histplot()
# - sns.kdeplot()
# - sns.displot()
# - sns.ecdfplot()

# %% [markdown]
# Histogram

# %%
sns.histplot(
    data=df,
    x="Math",
    bins=5
)

plt.show()

# %% [markdown]
# KDE plot

# %%
sns.kdeplot(
    data=df,
    x="Math",
    fill=True
)

plt.show()

# %% [markdown]
# #seaborn.regression
# Regression analysis.
#
# Graphs Used:
# - sns.regplot()
# - sns.lmplot()

# %% [markdown]
# Reg plot

# %%
sns.regplot(
    data=df,
    x="Hours",
    y="Math"
)

plt.show()

# %% [markdown]
# #seaborn.matrix
# Matrix visualization.
#
# Graphs Used:
# - sns.heatmap()
# - sns.clustermap()

# %% [markdown]
# Heatmap plot

# %%
corr = df[["Hours","Math","Science"]].corr()

sns.heatmap(
    corr,
    annot=True
)

plt.show()

# %% [markdown]
# clustermap plot

# %%
df_cluster = df.set_index("Student")

# %%
sns.clustermap(df_cluster)

plt.show()

# %%
sns.clustermap(
    df_cluster,
    standard_scale=1
)

plt.show()

# %% [markdown]
# #seaborn.axisgrid
# Multiple plots.
#
# Code Used:
# - sns.FacetGrid()
# - sns.PairGrid()
# - sns.JointGrid()

# %% [markdown]
# Pair plot

# %%
sns.pairplot(df)

plt.show()

# %% [markdown]
# Facet grid

# %%
g = sns.FacetGrid(
    df,
    col="Student"
)

g.map(sns.scatterplot,
      "Hours",
      "Math")

# %% [markdown]
# Joint plot

# %%
sns.jointplot(
    data=df,
    x="Hours",
    y="Math"
)

plt.show()

# %% [markdown]
# #MATPLOTLIB AND SEABORN

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset Creation

# %%
np.random.seed(42)

n = 300

data = {
    "Employee_ID": range(1001, 1001+n),

    "Gender": np.random.choice(
        ["Male", "Female"],
        n
    ),

    "Department": np.random.choice(
        ["IT", "HR", "Finance", "Marketing", "Operations"],
        n
    ),

    "Education": np.random.choice(
        ["Diploma", "Bachelor", "Master", "PhD"],
        n
    ),

    "Experience_Years": np.random.randint(
        1, 21, n
    ),

    "Age": np.random.randint(
        22, 60, n
    ),

    "Salary": np.random.randint(
        30000, 150000, n
    ),

    "Performance_Score": np.random.randint(
        50, 101, n
    ),

    "Work_Mode": np.random.choice(
        ["Remote", "Hybrid", "Onsite"],
        n
    ),

    "Satisfaction_Level": np.random.randint(
        1, 11, n
    )
}

df = pd.DataFrame(data)

df.to_csv("employee_dataset.csv", index=False)

print(df.head())

# %% [markdown]
# #Count Plot
# Count employees by department.
#
# What it shows
# - Frequency of categories
# - Which department has most employees
# - Useful for workforce distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="Department"
)

plt.title("Employees per Department")

plt.show()

# %% [markdown]
# #Bar Plot
# Average salary by department.
#
# What it shows
# - Compares mean salary
# - Useful for compensation analysis
# - Higher bars = higher average pay

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Department",
    y="Salary"
)

plt.title("Average Salary by Department")

plt.show()

# %% [markdown]
# #Histogram
# Salary distribution.
#
# What it shows
# - Shows frequency distribution
# - Detects skewness
# - Reveals salary ranges

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x="Salary",
    bins=20,
    kde=True
)

plt.title("Salary Distribution")

plt.show()

# %% [markdown]
# #KDE Plot
# Smooth salary distribution.
#
# What it shows
# - Smooth version of histogram
# - Peaks indicate common salary ranges
# - Useful for probability estimation

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(
    data=df,
    x="Salary",
    fill=True
)

plt.title("Salary Density")

plt.show()

# %% [markdown]
# #Scatter Plot
# Experience vs Salary.
#
# What it shows
# - Reveals relationships
# - Positive trend = more experience → - higher salary
# - Detects unusual employees

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Experience_Years",
    y="Salary"
)

plt.title("Experience vs Salary")

plt.show()

# %% [markdown]
# #Regression Plot
# Experience vs Salary with trend line.
#
# What it shows
# - Shows correlation strength
# - Trend line indicates expected salary growth

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df,
    x="Experience_Years",
    y="Salary"
)

plt.title("Regression Analysis")

plt.show()

# %% [markdown]
# #Box Plot
# Salary by department.
#
# What it shows
# - Median
# - Quartiles
# - Outliers
# - Salary variability

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Department",
    y="Salary"
)

plt.title("Salary Spread by Department")

plt.show()

# %% [markdown]
# #Violin Plot
#
# Combines:
#
# - Boxplot
# - Density distribution
#
# Wider sections indicate many employees in that salary range.

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    data=df,
    x="Department",
    y="Salary"
)

plt.title("Salary Distribution by Department")

plt.show()

# %% [markdown]
# #Strip Plot
# Interpretation
#
# Every dot = one employee.
#
# Useful for:
#
# - Raw observations
# - Detecting clusters

# %%
plt.figure(figsize=(8,5))

sns.stripplot(
    data=df,
    x="Department",
    y="Salary"
)

plt.title("Individual Salaries")

plt.show()

# %% [markdown]
# #Swarm Plot
# Interpretation
#
# Like strip plot but avoids overlap.

# %%
plt.figure(figsize=(8,5))

sns.swarmplot(
    data=df,
    x="Department",
    y="Salary"
)

plt.title("Salary Swarm Plot")

plt.show()

# %% [markdown]
# #Heatmap (Most Important)
# Correlation matrix.
#
# Useful for:
#
# - Feature selection
# - Machine learning

# %%
plt.figure(figsize=(8,6))

corr = df.select_dtypes(
    include="number"
).corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# #Pair Plot (EDA Favorite)
# Interpretation
#
# Automatically generates:
#
# - Scatter plots
# - Histograms
# - Relationships
#
# Excellent for exploration.

# %%
sns.pairplot(
    df[
        [
            "Age",
            "Salary",
            "Experience_Years",
            "Performance_Score"
        ]
    ]
)

plt.show()

# %% [markdown]
# #Hue-Based Scatter Plot
# Color by department.
#
# Interpretation
# - Compare groups visually
# - Detect department-specific trends

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Experience_Years",
    y="Salary",
    hue="Department"
)

plt.title("Experience vs Salary by Department")

plt.show()

# %% [markdown]
# #Line Plot
# Average salary by experience.
#
# Interpretation
#
# Shows trends across experience levels.

# %%
avg_salary = df.groupby(
    "Experience_Years"
)["Salary"].mean().reset_index()

sns.lineplot(
    data=avg_salary,
    x="Experience_Years",
    y="Salary"
)

plt.title("Average Salary Growth")

plt.show()

# %% [markdown]
# #FacetGrid
# Split graphs by work mode.
#
# Interpretation
#
# Creates separate charts for:
#
# - Remote
# - Hybrid
# - Onsite
#
# Useful for segmented analysis.

# %%
g = sns.FacetGrid(
    df,
    col="Work_Mode"
)

g.map(
    sns.histplot,
    "Salary"
)

plt.show()

# %% [markdown]
# #Joint Plot
# Interpretation
#
# Contains:
#
# - Scatter plot
# - X distribution
# - Y distribution
#
# Great for correlation analysis.

# %%
sns.jointplot(
    data=df,
    x="Experience_Years",
    y="Salary",
    kind="scatter"
)

plt.show()
