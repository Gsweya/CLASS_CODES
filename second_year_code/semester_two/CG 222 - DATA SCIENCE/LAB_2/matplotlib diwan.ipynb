# %% [markdown]
# #DATA SCIENCE

# %% [markdown]
# #Matplotlib
# popular Python library used for creating data visualizations such as line charts, bar charts, scatter plots, histograms, pie charts, and many more.

# %% [markdown]
# #widely used in
# - Data Science
# - Machine Learning
# - Scientific Research
# - Engineering
# - Business Analytics

# %% [markdown]
# #Main Components / Sub-packages of Matplotlib

# %% [markdown]
# #matplotlib.pyplot
# Provides MATLAB-like plotting functions
# - Example
#
# import matplotlib.pyplot as plt
#
# #Common Functions
# - plt.plot()
# - plt.scatter()
# - plt.bar()
# - plt.hist()
# - plt.pie()
# - plt.boxplot()
# - plt.xlabel()
# - plt.ylabel()
# - plt.title()
# - plt.legend()
# - plt.grid()
# - plt.show()
# - savefig()
# - subplot()
# - imshow()

# %% [markdown]
# #matplotlib.figure
# Used to create and manage figures.
# - Example
#
# from matplotlib.figure import Figure
#
# fig = plt.figure()
#
# #matplotlib.axes
# Represents an individual plot inside a figure.
# - Example
#
# fig, ax = plt.subplots()
#
# #matplotlib.animation
# Used to create animated graphs.
# - Example
#
# from matplotlib.animation import FuncAnimation
#
#
# Applications:
# - Real-time data monitoring
# - Simulations
# - Dynamic visualizations
#
# #matplotlib.colors
# Handles colors and color mapping.
# - Example
#
# from matplotlib import colors
#
# #matplotlib.image
# Read and display images.
# -Example
#
# import matplotlib.image as mpimg
#
# - Code
#
# img = mpimg.imread("image.png")
#
# plt.imshow(img)
#
# #matplotlib.patches
# Used for drawing shapes
#
# Example
# - Rectangle
# - Circle
# - Polygon
#
#
# from matplotlib.patches import Rectangle
#
#
# #matplotlib.style
# Apply predefined styles.
#
# plt.style.use('ggplot')
#
#
# Popular styles:
# - ggplot
# - classic
# - fast
# - dark_background

# %%
import pandas as pd

data = {
    "Student": ["A", "B", "C", "D", "E", "F"],
    "Math": [85, 78, 92, 70, 88, 95],
    "Science": [80, 85, 90, 75, 84, 98],
    "Hours_Studied": [5, 4, 6, 3, 5, 7]
}

data = pd.DataFrame(data)

# %%
data.head()
# Out:
#   Student  Math  Science  Hours_Studied
# 0       A    85       80              5
# 1       B    78       85              4
# 2       C    92       90              6
# 3       D    70       75              3
# 4       E    88       84              5

# %%
df = data

# %% [markdown]
# #Line Plot

# %%
import matplotlib.pyplot as plt

plt.plot(df["Student"], df["Math"], marker="o")

plt.title("Math Scores")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# #Bar Chart
# Compare categories

# %%
plt.bar(df["Student"], df["Math"])

plt.title("Math Scores")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# #Horizontal Bar Chart

# %%
plt.barh(df["Student"], df["Science"])

plt.title("Science Scores")

plt.show()

# %% [markdown]
# #Scatter Plot
# Relationship between study hours and marks

# %%
plt.scatter(df["Hours_Studied"],
            df["Math"])

plt.title("Study Hours vs Math Score")
plt.xlabel("Hours Studied")
plt.ylabel("Math Marks")

plt.show()

# %% [markdown]
# #Histogram
# Distribution of marks.

# %%
plt.hist(df["Math"],
         bins=5)

plt.title("Distribution of Math Scores")

plt.show()

# %% [markdown]
# #Pie Chart
# Percentage contribution of total math marks.

# %%
plt.pie(
    df["Math"],
    labels=df["Student"],
    autopct="%1.1f%%"
)

plt.title("Math Score Contribution")

plt.show()

# %% [markdown]
# #Box Plot
# Detect spread and outliers.

# %%
plt.boxplot(df["Math"])

plt.title("Math Scores Box Plot")

plt.show()

# %% [markdown]
# #Multiple Line Graphs
# Compare Math and Science scores.

# %%
plt.plot(df["Student"],
         df["Math"],
         marker="o",
         label="Math")

plt.plot(df["Student"],
         df["Science"],
         marker="s",
         label="Science")

plt.legend()

plt.title("Math vs Science")

plt.show()

# %% [markdown]
# #Subplots
# Display multiple graphs in one figure.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))

ax[0].bar(df["Student"], df["Math"])
ax[0].set_title("Math")

ax[1].bar(df["Student"], df["Science"])
ax[1].set_title("Science")

plt.tight_layout()
plt.show()

# %% [markdown]
# #Stack Plot
# Show combined subject performance.

# %%
x = range(len(df))

plt.stackplot(
    x,
    df["Math"],
    df["Science"],
    labels=["Math", "Science"]
)

plt.legend()
plt.title("Stack Plot")

plt.show()

# %% [markdown]
# #Area Plot

# %%
plt.fill_between(
    df["Student"],
    df["Math"],
    alpha=0.5
)

plt.title("Math Area Plot")

plt.show()

# %% [markdown]
# #Stem Plot

# %%
plt.stem(
    df["Hours_Studied"],
    df["Math"]
)

plt.title("Stem Plot")

plt.show()

# %% [markdown]
# #Animation Graph (Most Important)
# Animated Growing Line Chart

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

x = []
y = []

fig, ax = plt.subplots()

students = ["A", "B", "C", "D", "E", "F"]
scores = [85, 78, 92, 70, 88, 95]

def animate(i):
    x.append(students[i])
    y.append(scores[i])

    ax.clear()
    ax.plot(x, y, marker='o')

    ax.set_title("Animated Math Scores")
    ax.set_xlabel("Students")
    ax.set_ylabel("Marks")

ani = FuncAnimation(
    fig,
    animate,
    frames=len(students),
    interval=1000,
    repeat=False
)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7038828b32bf4b628c4626b8df0c480c">
#   <div class="anim-controls">
#     <input id="_anim_slider7038828b32bf4b628c4626b8df0c480c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7038828b32bf4b628c4626b8df0c480c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7038828b32bf4b628c4626b8df0c480c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7038828b32bf4b628c4626b8df0c480c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7038828b32bf4b628c4626b8df0c480c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7038828b32bf4b628c4626b8df0c480c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7038828b32bf4b628c4626b8df0c480c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7038828b32bf4b628c4626b8df0c480c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7038828b32bf4b628c4626b8df0c480c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7038828b32bf4b628c4626b8df0c480c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7038828b32bf4b628c4626b8df0c480c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7038828b32bf4b628c4626b8df0c480c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7038828b32bf4b628c4626b8df0c480c"
#              checked>
#       <label for="_anim_radio1_7038828b32bf4b628c4626b8df0c480c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7038828b32bf4b628c4626b8df0c480c"
#              >
#       <label for="_anim_radio2_7038828b32bf4b628c4626b8df0c480c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7038828b32bf4b628c4626b8df0c480c"
#              >
#       <label for="_anim_radio3_7038828b32bf4b628c4626b8df0c480c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7038828b32bf4b628c4626b8df0c480c";
#     var slider_id = "_anim_slider7038828b32bf4b628c4626b8df0c480c";
#     var loop_select_id = "_anim_loop_select7038828b32bf4b628c4626b8df0c480c";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjYsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvq6yFwwAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAALpdJRE

# %% [markdown]
# How it Works
# - FuncAnimation() repeatedly calls animate()
# - frames=6 → runs 6 times
# - interval=1000 → updates every 1 second
# - Each frame adds one new data point

# %% [markdown]
# #Real-Time Random Data Animation
# This simulates:
# - Stock prices
# - Sensor data
# - IoT dashboards
# - CPU monitoring

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import random

fig, ax = plt.subplots(figsize=(8,4))

x = []
y = []

line, = ax.plot([], [], marker='o')

ax.set_xlim(0, 100)
ax.set_ylim(50, 110)

ax.set_title("Live Score Stream")
ax.set_xlabel("Frame")
ax.set_ylabel("Score")

def animate(i):
    x.append(i)
    y.append(random.randint(60,100))

    line.set_data(x, y)
    return line,

ani = FuncAnimation(
    fig,
    animate,
    frames=100,
    interval=100,
    blit=True,
    cache_frame_data=False
)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9e3befe4daa04c89b52ee9d18f5cbb1c">
#   <div class="anim-controls">
#     <input id="_anim_slider9e3befe4daa04c89b52ee9d18f5cbb1c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9e3befe4daa04c89b52ee9d18f5cbb1c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9e3befe4daa04c89b52ee9d18f5cbb1c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9e3befe4daa04c89b52ee9d18f5cbb1c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9e3befe4daa04c89b52ee9d18f5cbb1c"
#              >
#       <label for="_anim_radio1_9e3befe4daa04c89b52ee9d18f5cbb1c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9e3befe4daa04c89b52ee9d18f5cbb1c"
#              checked>
#       <label for="_anim_radio2_9e3befe4daa04c89b52ee9d18f5cbb1c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9e3befe4daa04c89b52ee9d18f5cbb1c"
#              >
#       <label for="_anim_radio3_9e3befe4daa04c89b52ee9d18f5cbb1c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9e3befe4daa04c89b52ee9d18f5cbb1c";
#     var slider_id = "_anim_slider9e3befe4daa04c89b52ee9d18f5cbb1c";
#     var loop_select_id = "_anim_loop_select9e3befe4daa04c89b52ee9d18f5cbb1c";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjYsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvq6yFwwAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAANZpJ
